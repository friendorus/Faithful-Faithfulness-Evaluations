# %% [markdown]
# ## Check Saliency Size

# %%
import numpy as np

path = "/home/jovyan/work/MST/results/DINOv3ViTB/saliency_results/gradcam/class_2/npy/08FEB48B_right_importance.npy"

saliency = np.load(path)

print("Shape:", saliency.shape)
print("Dtype:", saliency.dtype)
print("Min:", saliency.min())
print("Max:", saliency.max())
print("Mean:", saliency.mean())
# Out:
# Shape: (32, 224, 224)
# Dtype: float32
# Min: 0.0
# Max: 0.99997663
# Mean: 0.041761555

# %%
import matplotlib.pyplot as plt

plt.imshow(saliency[0], cmap='hot')
plt.title("Slice 0")
plt.colorbar()
plt.show()
